# %%
import numpy as np
from research.logreg import fit_and_score, pred_grid, show_pred, make_train_test
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
train_test = X_train, X_test, y_train, y_test = make_train_test()

# %%
results = {degree: fit_and_score(degree=degree, train_test=train_test, C=10.0) for degree in range(1, 10)}
for result in sorted(results):
    print(f'{f" Model results for degree: {result} ":*^80}\n')
    print(results[result][1])
# Out:
# ************************* Model results for degree: 1 **************************
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.86      0.84        44
#            1       0.89      0.86      0.87        56
#
#    micro avg       0.86      0.86      0.86       100
#    macro avg       0.86      0.86      0.86       100
# weighted avg       0.86      0.86      0.86       100
#
# ************************* Model results for degree: 2 **************************
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.86      0.84        44
#            1       0.89      0.86      0.87        56
#
#    micro avg       0.86      0.86      0.86       100
#    macro avg       0.86      0.86      0.86       100
# weighted avg       0.86      0.86      0.86       100
#
# ************************* Model results for degree: 3 **************************
#
#               precision    recall  f1-score   support
#
# ...

# %%
m1 = results[1][0]
m1.named_steps['logisticregression'].coef_, m1.named_steps['logisticregression'].intercept_
# Out:
# (array([[ 0.        ,  1.06382763, -2.58461724]]), array([-0.04994921]))

# %%
lrbt = -2.0, 3.0, -1.5, 2.0
n = 100
show_pred(results[4][0], X_train, y_train, lrbt, n)
